# %%
import subprocess
print(subprocess.run(["pip", "freeze"], stdout=subprocess.PIPE, text=True).stdout)
# Out:
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.3
# argcomplete==1.12.0
# argh==0.26.2
# asn1crypto==1.3.0
# astroid==2.4.1
# astropy==4.0.1.post1
# atomicwrites==1.4.0
# attrs==19.3.0
# autopep8==1.4.4
# Babel==2.8.0
# backcall==0.1.0
# backports.functools-lru-cache==1.6.1
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.9.1
# biopython==1.79
# bitarray==1.2.2
# bkcharts==0.2
# bleach==3.1.4
# bokeh==2.0.2
# boto==2.49.0
# Bottleneck==1.3.2
# certifi==2021.5.30
# cffi==1.14.0
# chardet==3.0.4
# click==7.1.2
# cloudpickle==1.4.1
# clyent==1.2.2
# colorama==0.4.3
# conda==4.10.3
# conda-build==3.18.9
# conda-package-handling==1.7.0
# conda-verify==3.4.2
# contextlib2==0.6.0.post1
# cryptography==2.9.2
# cycler==0.10.0
# Cython==0.29.17
# cytoolz==0.10.1
# dask==2.17.2
# decorator==4.4.2
# defusedxml==0.6.0
# diff-match-patch==20181111
# ...
